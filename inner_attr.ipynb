# %% [markdown]
# # Inner Attribute
# 内在属性访问
# `__dir__()` or `dir()`访问x对象的所有属性返回字典
# `__getattribute__()` or `getattr(x,name)`

# %%
for each in x.__dir__():
    attr_name=each
    attr_value=x.__getattribute__(each)
    print(attr_name,':',attr_value)
