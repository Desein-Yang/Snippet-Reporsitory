# %% [markdown]
# # Matplotlib

# %% [markdown]
# ## Simple plot
# 最简单的折线图,t为x,s或f(t)为y,设置子图一种是ax.set，一种是plt.xlabel()
# - ax.set(xlabel="",ylabel=""....)
# - plt.xlabel("")
# - plt.xlim()
# - plt.savefig(filename)
# - plt.title()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# Data for plotting
t = np.arange(0.0, 2.0, 0.01)
s = 1 + np.sin(2 * np.pi * t)
def f(x):
    return 1 + np.sin(2 * np.pi * t)

fig, ax = plt.subplots()
ax.plot(t, s)
ax.plot(t, f(t))

ax.set(xlabel='time (s)', ylabel='voltage (mV)',
       title='About as simple as it gets, folks')
ax.grid()

# fig.savefig("test.png")
plt.show()

# %% [markdown]
# ## Subplot
# subplot(abc)
# - a is row
# - b is col
# - c is num

# %%
names = ['group_a', 'group_b', 'group_c']
values = [1, 10, 100]

plt.figure(figsize=(9, 3))

plt.subplot(131)
plt.bar(names, values)
plt.subplot(132)
plt.scatter(names, values)
plt.subplot(133)
plt.plot(names, values)
plt.suptitle('Categorical Plotting')
plt.show()

# %% [markdown]
# ## Line
#
# 设置方法有两种
# - plot 中加attr=""
# - setp()
#
# Attr:
# marker  '+' | ',' | '.' | '1' | '2' | '3' | '4'
# linestyle or ls  '-' | '--' | '-.' | ':' | 'steps' | ...
# linewidth or lw float value in points
# markeredgecolor or mec any matplotlib color
# markeredgewidth or mew float value in points
# markerfacecolor or mfc any matplotlib color
# markersize or ms float

# %%
ax.plot(t, s, linewidth = 5, )

lines = plt.plot(t, x1, t, x2)
plt.setp(lines, color='r', linewidth=2.0)

# %% [markdown]
# ## Color
# 一般用RGB值或 #FFFFFF 或名字'r','g','orange'
# 设置color = 'C0'时用的是seaborn高级配色
#
#
# color library:https://www.matplotlib.org.cn/tutorials/colors/colors.html#xkcd-v-x11-css4

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

th = np.linspace(0, 2*np.pi, 128)

def demo(sty):
    mpl.style.use(sty)
    fig, ax = plt.subplots(figsize=(3, 3))

    ax.set_title('style: {!r}'.format(sty), color='C0')

    ax.plot(th, np.cos(th), 'C1', label='C1')
    ax.plot(th, np.sin(th), 'C2', label='C2')
    ax.legend()

demo('default')
demo('seaborn')

# %% [markdown]
# ## Ref
#
# 教程：https://www.matplotlib.org.cn/tutorials/

# %% [markdown]
# # Seaborn
#
# 配色和图比matplotlib好看多了，整体显得比较高级

# %%
# libraries
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

x = np.linspace(0, 2*np.pi, 128)
y = np.sin(x)

def draw(x,y):
    fig, ax = plt.subplots(figsize=(3, 3))
    ax.plot(th, np.cos(th), 'C1', label='C1')
    ax.set(xlabel='x',ylabel='y',title='example')

draw(x,y)

# %% [markdown]
# ## Ref
#
# Seaborn 教程图库：https://python-graph-gallery.com/seaborn/
