# %% [markdown]
# # Matplotlib

# %% [markdown]
# ## Simple plot
# 最简单的折线图,t为x,s或f(t)为y,设置子图一种是ax.set，一种是plt.xlabel()
# - ax.set(xlabel="",ylabel=""....)
# - plt.xlabel("")
# - plt.xlim()
# - plt.savefig(filename)
# - plt.title()
# - plt.legend()
# plt.legend(loc='upper center', bbox_to_anchor=(0.6,0.95),ncol=3,fancybox=True,shadow=True)
# https://matplotlib.org/api/legend_api.html?highlight=legend#module-matplotlib.legend

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# Data for plotting
t = np.arange(0.0, 2.0, 0.01)
s = 1 + np.sin(2 * np.pi * t)
def f(x):
    return 1 + np.sin(2 * np.pi * t)

fig, ax = plt.subplots()
ax.plot(t, s)
ax.plot(t, f(t))

ax.set(xlabel='time (s)', ylabel='voltage (mV)',
       title='About as simple as it gets, folks')
ax.grid()

# fig.savefig("test.png")
plt.show()

# %% [markdown]
# ## text

# %%
for _x, _y in zip(bins1, freq1):
    plt.text(_x, _y + 0.1, '%.2f' % _y, ha='center', va='top', size=8)

# %% [markdown]
# ## Subplot
# subplot(abc)
# - a is row
# - b is col
# - c is num

# %%
names = ['group_a', 'group_b', 'group_c']
values = [1, 10, 100]

plt.figure(figsize=(9, 3))

plt.subplot(131)
plt.bar(names, values)
plt.subplot(132)
plt.scatter(names, values)
plt.subplot(133)
plt.plot(names, values)
plt.suptitle('Categorical Plotting') # 总图标题
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e15e2ceee538> in <module>
#       2 values = [1, 10, 100]
#       3
# ----> 4 plt.figure(figsize=(9, 3))
#       5
#       6 plt.subplot(131)
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ### 去掉边框

# %%
for key, spine in ax.spines.items():
    # 'left', 'right', 'bottom', 'top'
    if key == 'right' or key == 'top':
        spine.set_visible(False)

# %% [markdown]
# ## Set params
#
# https://blog.csdn.net/helunqu2017/article/details/78652261

# %%
def set():
    plt.rcParams['savefig.dpi'] = 600 #图片像素
    plt.rcParams['figure.dpi'] = 300 #分辨率
    plt.rcParams['figure.figsize'] = (4,3.5)
    matplotlib.style.use('seaborn-paper')
    # the style can be seen in matplotlib.style.available

# %% [markdown]
# ## Line
#
# 设置方法有两种
# - plot 中加attr=""
# - setp()
#
# Attr:
# marker  '+' | ',' | '.' | '1' | '2' | '3' | '4'
# linestyle or ls  '-' | '--' | '-.' | ':' | 'steps' | ...
# linewidth or lw float value in points
# markeredgecolor or mec any matplotlib color
# markeredgewidth or mew float value in points
# markerfacecolor or mfc any matplotlib color
# markersize or ms float
#
# 字符|类型 | 字符|类型
# ---|--- | --- | ---
# `  '-'	`| 实线 | `'--'`|	虚线
# `'-.'`|	虚点线 | `':'`|	点线
# `'.'`|	点 | `','`| 像素点
# `'o'`	|圆点 | `'v'`|	下三角点
# `'^'`|	上三角点 | `'<'`|	左三角点
# `'>'`|	右三角点 | `'1'`|	下三叉点
# `'2'`|	上三叉点 | `'3'`|	左三叉点
# `'4'`|	右三叉点 | `'s'`|	正方点
# `'p'`	| 五角点 | `'*'`|	星形点
# `'h'`|	六边形点1 | `'H'`|	六边形点2
# `'+'`|	加号点 | `'x'`|	乘号点
# `'D'`|	实心菱形点 | `'d'`|	瘦菱形点
# `'_'`|	横线点 | |
#
# 字符 | 颜色
# -- | --
# `‘b’`|	蓝色，blue
# `‘g’`|	绿色，green
# `‘r’`|	红色，red
# `‘c’`|	青色，cyan
# `‘m’`|	品红，magenta
# `‘y’`|	黄色，yellow
# `‘k’`|	黑色，black
# `‘w’`|	白色，white

# %%
ax.plot(t, s, linewidth = 5, )

lines = plt.plot(t, x1, t, x2)
plt.setp(lines, color='r', linewidth=2.0)

# %% [markdown]
# ### 平滑折线

# %%
import numpy as np
from scipy import interpolate
import matplotlib.pyplot as plt

x = np.linspace(-np.pi, np.pi, 10)
y = np.sin(x)
plt.plot(x, y)

f = interpolate.interp1d(x, y, kind='cubic')
nx = np.linspace(-np.pi, np.pi, 30)
ny = f(nx)
plt.plot(nx, ny)
plt.show()

# %% [markdown]
# ## Dpi

# %%
plt.rcParams['savefig.dpi'] = 300 #图片像素
plt.rcParams['figure.dpi'] = 600 #分辨率
plt.rcParams['figure.figsize'] = (8.0, 4.0) # 设置figure_size尺寸
plt.rcParams['image.interpolation'] = 'nearest' # 设置 interpolation style
plt.rcParams['image.cmap'] = 'gray' # 设置 颜色 style

# %% [markdown]
# ## save
# 存储为eps格式的透明的问题
# https://stackoverflow.com/questions/19638773/matplotlib-plots-lose-transparency-when-saving-as-ps-eps
# 存储图相比于显示图剪切轴标签问题（rcParams尺寸）
#
# 1. 你可以使用plt.tight_layout()让matplotlib调整你的情节布局. tight_layout()将自动调整尺寸,也可以在(例如)重叠标签/刻度/等时使用.似乎没什么用，只会去掉我的轴标签。
# 2. plt.rcParams['savefig.bbox'] = 'tight'意思是自动调整布局找出tight box

# %%
# %pylab inline

pylab.rcParams['figure.figsize'] = (8.0, 2.0)

plot([1,5,2,4,6,2,1])

xlabel("$x$")
ylabel("$y$")

tight_layout()

savefig("test.pdf")

# %% [markdown]
# ## Color
# 一般用RGB值或 #FFFFFF 或名字'r','g','orange'
# 设置color = 'C0'时用的是seaborn高级配色
#
#
# color library:https://www.matplotlib.org.cn/tutorials/colors/colors.html#xkcd-v-x11-css4
# https://finthon.com/matplotlib-color-list/
#
# 色带设置
# https://blog.csdn.net/liuchengzimozigreat/article/details/90477501

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

th = np.linspace(0, 2*np.pi, 128)

def demo(sty):
    mpl.style.use(sty)
    fig, ax = plt.subplots(figsize=(3, 3))

    ax.set_title('style: {!r}'.format(sty), color='C0')

    ax.plot(th, np.cos(th), 'C1', label='C1')
    ax.plot(th, np.sin(th), 'C2', label='C2')
    ax.legend()

demo('default')
demo('seaborn')

# %% [markdown]
# ## Ref
#
# 教程：https://www.matplotlib.org.cn/tutorials/

# %% [markdown]
# # Seaborn
#
# 配色和图比matplotlib好看多了，整体显得比较高级

# %%
# libraries
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

x = np.linspace(0, 2*np.pi, 128)
y = np.sin(x)

def draw(x,y):
    fig, ax = plt.subplots(figsize=(3, 3))
    ax.plot(th, np.cos(th), 'C1', label='C1')
    ax.set(xlabel='x',ylabel='y',title='example')

draw(x,y)

# %% [markdown]
# ## Ref
#
# Seaborn 教程图库：https://python-graph-gallery.com/seaborn/
